# %%
import glob
import pandas as pd
import numpy as np

from matplotlib import pyplot as plt

# %%
files = glob.glob("./csv/*.csv")
df = pd.concat((pd.read_csv(f) for f in files))
df["date"] = pd.to_datetime(df["date"])
df = df.set_index(["date", "ticker"]).sort_index()

# %%
def trim_99(column):
    """
    Trims data to between 1st and 99th percentile of original.
    Sets values lower than 1 percentile and greater than 99 percentile
    to nan.
    """
    upper = np.percentile(column, 99)
    lower = np.percentile(column, 1)
    return column.mask((column > upper) | (column < lower), other=np.nan)

# %%
# Filters
df = df.replace([np.inf, -np.inf], np.nan)
df = df.apply(trim_99, axis=0)
df = df.dropna()

# %%
num_dates = len(df.index.levels[0])
break_point = int(0.75 * num_dates)
train_index = df.index.levels[0][:break_point]
test_index = df.index.levels[0][break_point:]

train_data = df.loc[train_index]
test_data = df.loc[test_index]

# %%
def train_test_iter(df, n_splits):
    """
    Yield train and test indexes for cross validation.
    Expects multiindex dataframe with dates as first level of index.
    Intended for panel data and creates training data with expanding window.
    """
    # Extract dates
    dates = df.index.levels[0]
    # From number of splits, determine number of samples in each dataset
    window_size = int(len(dates) / n_splits)
    for i in range(1, n_splits):
        # Find where training window ends, multiply by i to create expanding window
        break_point = window_size * i
        train_index = dates[:break_point]
        # If we're on the last iteration, return all remaining data as test set
        # to account for remainders in window size across n_splits
        # otherwise return test data of size 'window_size'
        if i == (n_splits - 1):
            test_index = dates[break_point:]
        else:
            test_index = dates[break_point:(break_point + window_size)]
        yield train_index, test_index

# %%
x = train_data.drop(columns=["monthly_ret", "forward_ret"])
y = train_data["forward_ret"]

x_test = test_data.drop(columns=["monthly_ret", "forward_ret"])
y_test = test_data["forward_ret"]

# %%
import torch
import torch.nn as nn

# %%
class MLP(nn.Module):
    def __init__(self, in_dim, out_dim, hidden_dim):
        super().__init__()
        self.network = nn.Sequential(
            nn.Linear(in_dim, hidden_dim),
            nn.ELU(),
            nn.Dropout(),
            nn.Linear(hidden_dim, out_dim)
        )
    
    def forward(self, x):
        return self.network(x)

# %%
torch_x = torch.Tensor(x.values)
torch_y = torch.Tensor(y.values).reshape(-1, 1)

in_dim = torch_x.shape[1]

# %%
model = MLP(in_dim, 1, 8)
optim = torch.optim.AdamW(model.parameters(), lr=0.001)
loss = nn.MSELoss()

train_losses = []
validation_losses = []
model.train()
for epoch in range(500):
    optim.zero_grad()
    output = model(torch_x)
    
    train_loss = loss(output, torch_y)
    print(train_loss)
    train_losses.append(train_loss.detach())
    
    train_loss.backward()
    optim.step()
# Out:
# tensor(8107.9336, grad_fn=<MseLossBackward>)
# tensor(7030.9507, grad_fn=<MseLossBackward>)
# tensor(16076.0059, grad_fn=<MseLossBackward>)
# tensor(20786.2441, grad_fn=<MseLossBackward>)
# tensor(10461.3740, grad_fn=<MseLossBackward>)
# tensor(11928.0723, grad_fn=<MseLossBackward>)
# tensor(18499.4082, grad_fn=<MseLossBackward>)
# tensor(12235.5947, grad_fn=<MseLossBackward>)
# tensor(13116.7002, grad_fn=<MseLossBackward>)
# tensor(9900.9932, grad_fn=<MseLossBackward>)
# tensor(26076.9824, grad_fn=<MseLossBackward>)
# tensor(16006.7686, grad_fn=<MseLossBackward>)
# tensor(3585.1030, grad_fn=<MseLossBackward>)
# tensor(7987.2202, grad_fn=<MseLossBackward>)
# tensor(3069.7007, grad_fn=<MseLossBackward>)
# tensor(8170.0957, grad_fn=<MseLossBackward>)
# tensor(14759.1934, grad_fn=<MseLossBackward>)
# tensor(8616.8252, grad_fn=<MseLossBackward>)
# tensor(19823.6660, grad_fn=<MseLossBackward>)
# tensor(3370.7878, grad_fn=<MseLossBackward>)
# tensor(2842.7896, grad_fn=<MseLossBackward>)
# tensor(17061.6992, grad_fn=<MseLossBackward>)
# tensor(2390.6443, grad_fn=<MseLossBackward>)
# tensor(12717.4717, grad_fn=<MseLossBackward>)
# tensor(252.1186, grad_fn=<MseLossBackward>)
# tensor(1586.4299, grad_fn=<MseLossBackward>)
# tensor(2020.4862, grad_fn=<MseLossBackward>)
# tensor(15250.8975, grad_fn=<MseLossBackward>)
# tensor(2908.3235, grad_fn=<MseLossBackward>)
# tensor(1797.5040, grad_fn=<MseLossBackward>)
# tensor(2541.0811, grad_fn=<MseLossBackward>)
# tensor(1929.9092, grad_fn=<MseLossBackward>)
# tensor(10092.3877, grad_fn=<MseLossBackward>)
# tensor(12182.2139, grad_fn=<MseLossBackward>)
# tensor(6470.9199, grad_fn=<MseLossBackward>)
# tensor(1931.4528, grad_fn=<MseLossBackward>)
# tensor(8963.3994, grad_fn=<MseLossBackward>)
# tensor(5832.5737, grad_fn=<MseLossBackward>)
# tensor(6768.7451, grad_fn=<MseLossBackward>)
# tensor(515.6385, grad_fn=<MseLossBackward>)
# tensor(2614.0149, grad_fn=<MseLossBackward>)
# tensor(2449.1123, grad_fn=<MseLossBackward>)
# tensor(2230.9866, grad_fn=<MseLossBackward>)
# tensor(2304.3125, grad_fn=<MseLossBackward>)
# tensor(4529.9858, grad_fn=<MseLossBackward>)
# tensor(6864.9111, grad_fn=<MseLossBackward>)
# tensor(9761.0547, grad_fn=<MseLossBackward>)
# tensor(1786.6064, grad_fn=<MseLossBackward>)
# tensor(1569.9071, grad_fn=<MseLossBackward>)
# tensor(3473.3674, grad_fn=<MseLossBackward>)
# tensor(5689.1641, grad_fn=<MseLossBackward>)
# tensor(2260.0522, grad_fn=<MseLossBackward>)
# tensor(1569.6561, grad_fn=<MseLossBackward>)
# tensor(767.5899, grad_fn=<MseLossBackward>)
# tensor(1958.8595, grad_fn=<MseLossBackward>)
# tensor(870.9678, grad_fn=<MseLossBackward>)
# tensor(1053.5962, grad_fn=<MseLossBackward>)
# tensor(1038.7523, grad_fn=<MseLossBackward>)
# tensor(1636.3486, grad_fn=<MseLossBackward>)
# tensor(992.5120, grad_fn=<MseLossBackward>)
# tensor(4834.6191, grad_fn=<MseLossBackward>)
# tensor(1500.2632, grad_fn=<MseLossBackward>)
# tensor(5676.9316, grad_fn=<MseLossBackward>)
# tensor(5585.3887, grad_fn=<MseLossBackward>)
# tensor(4227.5405, grad_fn=<MseLossBackward>)
# tensor(529.0057, grad_fn=<MseLossBackward>)
# tensor(1407.1588, grad_fn=<MseLossBackward>)
# tensor(5259.1626, grad_fn=<MseLossBackward>)
# tensor(1266.9875, grad_fn=<MseLossBackward>)
# tensor(1647.6810, grad_fn=<MseLossBackward>)
# tensor(2165.8713, grad_fn=<MseLossBackward>)
# tensor(672.9575, grad_fn=<MseLossBackward>)
# tensor(1255.3335, grad_fn=<MseLossBackward>)
# tensor(3638.8564, grad_fn=<MseLossBackward>)
# tensor(1139.2411, grad_fn=<MseLossBackward>)
# tensor(854.1771, grad_fn=<MseLossBackward>)
# tensor(1457.8560, grad_fn=<MseLossBackward>)
# tensor(803.4139, grad_fn=<MseLossBackward>)
# tensor(1292.9478, grad_fn=<MseLossBackward>)
# tensor(2249.4287, grad_fn=<MseLossBackward>)
# tensor(5668.4292, grad_fn=<MseLossBackward>)
# tensor(1340.2327, grad_fn=<MseLossBackward>)
# tensor(5414.6299, grad_fn=<MseLossBackward>)
# tensor(2628.6533, grad_fn=<MseLossBackward>)
# tensor(2281.3115, grad_fn=<MseLossBackward>)
# tensor(3568.8989, grad_fn=<MseLossBackward>)
# tensor(3315.6028, grad_fn=<MseLossBackward>)
# tensor(647.3658, grad_fn=<MseLossBackward>)
# tensor(1162.6412, grad_fn=<MseLossBackward>)
# tensor(1697.7605, grad_fn=<MseLossBackward>)
# tensor(2304.6904, grad_fn=<MseLossBackward>)
# tensor(753.4550, grad_fn=<MseLossBackward>)
# tensor(4521.1118, grad_fn=<MseLossBackward>)
# tensor(608.5367, grad_fn=<MseLossBackward>)
# tensor(2081.3950, grad_fn=<MseLossBackward>)
# tensor(2408.6755, grad_fn=<MseLossBackward>)
# tensor(1007.0940, grad_fn=<MseLossBackward>)
# tensor(1079.9946, grad_fn=<MseLossBackward>)
# tensor(3207.6550, grad_fn=<MseLossBackward>)
# tensor(987.7537, grad_fn=<MseLossBackward>)
# tensor(1139.1923, grad_fn=<MseLossBackward>)
# tensor(245.2999, grad_fn=<MseLossBackward>)
# tensor(902.2437, grad_fn=<MseLossBackward>)
# tensor(1942.4047, grad_fn=<MseLossBackward>)
# tensor(172.2124, grad_fn=<MseLossBackward>)
# tensor(3281.4258, grad_fn=<MseLossBackward>)
# tensor(904.6049, grad_fn=<MseLossBackward>)
# tensor(1627.2538, grad_fn=<MseLossBackward>)
# tensor(961.3582, grad_fn=<MseLossBackward>)
# tensor(32.7304, grad_fn=<MseLossBackward>)
# tensor(842.3494, grad_fn=<MseLossBackward>)
# tensor(937.7805, grad_fn=<MseLossBackward>)
# tensor(2122.3049, grad_fn=<MseLossBackward>)
# tensor(2799.7104, grad_fn=<MseLossBackward>)
# tensor(2056.6367, grad_fn=<MseLossBackward>)
# tensor(919.5073, grad_fn=<MseLossBackward>)
# tensor(1309.3192, grad_fn=<MseLossBackward>)
# tensor(1349.8563, grad_fn=<MseLossBackward>)
# tensor(1410.8301, grad_fn=<MseLossBackward>)
# tensor(151.9915, grad_fn=<MseLossBackward>)
# tensor(1896.8634, grad_fn=<MseLossBackward>)
# tensor(2390.1538, grad_fn=<MseLossBackward>)
# tensor(1262.9899, grad_fn=<MseLossBackward>)
# tensor(1272.6750, grad_fn=<MseLossBackward>)
# tensor(1177.2308, grad_fn=<MseLossBackward>)
# tensor(115.3742, grad_fn=<MseLossBackward>)
# tensor(101.8492, grad_fn=<MseLossBackward>)
# tensor(1765.4662, grad_fn=<MseLossBackward>)
# tensor(1073.4467, grad_fn=<MseLossBackward>)
# tensor(1020.4041, grad_fn=<MseLossBackward>)
# tensor(64.8847, grad_fn=<MseLossBackward>)
# tensor(780.3726, grad_fn=<MseLossBackward>)
# tensor(803.4238, grad_fn=<MseLossBackward>)
# tensor(38.6908, grad_fn=<MseLossBackward>)
# tensor(647.8895, grad_fn=<MseLossBackward>)
# tensor(87.3626, grad_fn=<MseLossBackward>)
# tensor(914.7078, grad_fn=<MseLossBackward>)
# tensor(1771.7676, grad_fn=<MseLossBackward>)
# tensor(40.0432, grad_fn=<MseLossBackward>)
# tensor(119.0696, grad_fn=<MseLossBackward>)
# tensor(870.5878, grad_fn=<MseLossBackward>)
# tensor(850.6977, grad_fn=<MseLossBackward>)
# tensor(75.8009, grad_fn=<MseLossBackward>)
# tensor(950.1066, grad_fn=<MseLossBackward>)
# tensor(816.0686, grad_fn=<MseLossBackward>)
# tensor(1319.7880, grad_fn=<MseLossBackward>)
# tensor(88.0727, grad_fn=<MseLossBackward>)
# tensor(162.5039, grad_fn=<MseLossBackward>)
# tensor(788.9172, grad_fn=<MseLossBackward>)
# tensor(1298.9386, grad_fn=<MseLossBackward>)
# tensor(782.7112, grad_fn=<MseLossBackward>)
# tensor(590.7374, grad_fn=<MseLossBackward>)
# tensor(76.4475, grad_fn=<MseLossBackward>)
# tensor(60.1505, grad_fn=<MseLossBackward>)
# tensor(61.1010, grad_fn=<MseLossBackward>)
# tensor(553.0740, grad_fn=<MseLossBackward>)
# tensor(545.9928, grad_fn=<MseLossBackward>)
# tensor(654.1033, grad_fn=<MseLossBackward>)
# tensor(976.4203, grad_fn=<MseLossBackward>)
# tensor(669.4877, grad_fn=<MseLossBackward>)
# tensor(204.6814, grad_fn=<MseLossBackward>)
# tensor(473.7126, grad_fn=<MseLossBackward>)
# tensor(1302.6285, grad_fn=<MseLossBackward>)
# tensor(441.2734, grad_fn=<MseLossBackward>)
# tensor(470.4338, grad_fn=<MseLossBackward>)
# tensor(149.8300, grad_fn=<MseLossBackward>)
# tensor(620.2462, grad_fn=<MseLossBackward>)
# tensor(1050.9764, grad_fn=<MseLossBackward>)
# tensor(902.9083, grad_fn=<MseLossBackward>)
# tensor(42.9522, grad_fn=<MseLossBackward>)
# tensor(470.2202, grad_fn=<MseLossBackward>)
# tensor(415.1774, grad_fn=<MseLossBackward>)
# tensor(23.0637, grad_fn=<MseLossBackward>)
# tensor(404.1309, grad_fn=<MseLossBackward>)
# tensor(372.3890, grad_fn=<MseLossBackward>)
# tensor(557.8058, grad_fn=<MseLossBackward>)
# tensor(583.0844, grad_fn=<MseLossBackward>)
# tensor(605.8683, grad_fn=<MseLossBackward>)
# tensor(196.0518, grad_fn=<MseLossBackward>)
# tensor(88.2988, grad_fn=<MseLossBackward>)
# tensor(625.3077, grad_fn=<MseLossBackward>)
# tensor(544.6855, grad_fn=<MseLossBackward>)
# tensor(128.0196, grad_fn=<MseLossBackward>)
# tensor(500.3230, grad_fn=<MseLossBackward>)
# tensor(339.9665, grad_fn=<MseLossBackward>)
# tensor(410.0468, grad_fn=<MseLossBackward>)
# tensor(346.3609, grad_fn=<MseLossBackward>)
# tensor(584.3281, grad_fn=<MseLossBackward>)
# tensor(843.7716, grad_fn=<MseLossBackward>)
# tensor(5.0834, grad_fn=<MseLossBackward>)
# tensor(924.3154, grad_fn=<MseLossBackward>)
# tensor(486.9303, grad_fn=<MseLossBackward>)
# tensor(105.8371, grad_fn=<MseLossBackward>)
# tensor(475.9043, grad_fn=<MseLossBackward>)
# tensor(874.7952, grad_fn=<MseLossBackward>)
# tensor(12.5432, grad_fn=<MseLossBackward>)
# tensor(652.9130, grad_fn=<MseLossBackward>)
# tensor(525.4619, grad_fn=<MseLossBackward>)
# tensor(264.1717, grad_fn=<MseLossBackward>)
# tensor(23.7083, grad_fn=<MseLossBackward>)
# tensor(66.9349, grad_fn=<MseLossBackward>)
# tensor(105.9178, grad_fn=<MseLossBackward>)
# tensor(55.9922, grad_fn=<MseLossBackward>)
# tensor(394.4296, grad_fn=<MseLossBackward>)
# tensor(409.2939, grad_fn=<MseLossBackward>)
# tensor(13.3341, grad_fn=<MseLossBackward>)
# tensor(106.4465, grad_fn=<MseLossBackward>)
# tensor(413.3377, grad_fn=<MseLossBackward>)
# tensor(247.5684, grad_fn=<MseLossBackward>)
# tensor(609.1597, grad_fn=<MseLossBackward>)
# tensor(550.2241, grad_fn=<MseLossBackward>)
# tensor(294.9582, grad_fn=<MseLossBackward>)
# tensor(646.4880, grad_fn=<MseLossBackward>)
# tensor(223.3405, grad_fn=<MseLossBackward>)
# tensor(201.3061, grad_fn=<MseLossBackward>)
# tensor(331.8242, grad_fn=<MseLossBackward>)
# tensor(70.8973, grad_fn=<MseLossBackward>)
# tensor(248.1131, grad_fn=<MseLossBackward>)
# tensor(86.9347, grad_fn=<MseLossBackward>)
# tensor(81.6055, grad_fn=<MseLossBackward>)
# tensor(120.1200, grad_fn=<MseLossBackward>)
# tensor(187.3185, grad_fn=<MseLossBackward>)
# tensor(557.2578, grad_fn=<MseLossBackward>)
# tensor(444.6668, grad_fn=<MseLossBackward>)
# tensor(317.0632, grad_fn=<MseLossBackward>)
# tensor(58.9818, grad_fn=<MseLossBackward>)
# tensor(177.1107, grad_fn=<MseLossBackward>)
# tensor(285.4616, grad_fn=<MseLossBackward>)
# tensor(328.4670, grad_fn=<MseLossBackward>)
# tensor(545.4838, grad_fn=<MseLossBackward>)
# tensor(62.0181, grad_fn=<MseLossBackward>)
# tensor(272.4991, grad_fn=<MseLossBackward>)
# tensor(178.1422, grad_fn=<MseLossBackward>)
# tensor(283.0626, grad_fn=<MseLossBackward>)
# tensor(161.5166, grad_fn=<MseLossBackward>)
# tensor(84.7539, grad_fn=<MseLossBackward>)
# tensor(256.0117, grad_fn=<MseLossBackward>)
# tensor(152.9921, grad_fn=<MseLossBackward>)
# tensor(96.2201, grad_fn=<MseLossBackward>)
# tensor(300.7280, grad_fn=<MseLossBackward>)
# tensor(351.0671, grad_fn=<MseLossBackward>)
# tensor(146.0439, grad_fn=<MseLossBackward>)
# tensor(175.9968, grad_fn=<MseLossBackward>)
# tensor(111.7206, grad_fn=<MseLossBackward>)
# tensor(152.7830, grad_fn=<MseLossBackward>)
# tensor(349.4801, grad_fn=<MseLossBackward>)
# tensor(30.7472, grad_fn=<MseLossBackward>)
# tensor(104.2762, grad_fn=<MseLossBackward>)
# tensor(335.1635, grad_fn=<MseLossBackward>)
# tensor(112.3006, grad_fn=<MseLossBackward>)
# tensor(298.0613, grad_fn=<MseLossBackward>)
# tensor(129.8843, grad_fn=<MseLossBackward>)
# tensor(231.1056, grad_fn=<MseLossBackward>)
# tensor(248.5231, grad_fn=<MseLossBackward>)
# tensor(64.4766, grad_fn=<MseLossBackward>)
# tensor(81.1903, grad_fn=<MseLossBackward>)
# tensor(249.5941, grad_fn=<MseLossBackward>)
# tensor(33.3247, grad_fn=<MseLossBackward>)
# tensor(84.8786, grad_fn=<MseLossBackward>)
# tensor(52.1179, grad_fn=<MseLossBackward>)
# tensor(205.4867, grad_fn=<MseLossBackward>)
# tensor(35.8900, grad_fn=<MseLossBackward>)
# tensor(202.4593, grad_fn=<MseLossBackward>)
# tensor(26.5967, grad_fn=<MseLossBackward>)
# tensor(226.8929, grad_fn=<MseLossBackward>)
# tensor(358.9151, grad_fn=<MseLossBackward>)
# tensor(10.9620, grad_fn=<MseLossBackward>)
# tensor(233.4830, grad_fn=<MseLossBackward>)
# tensor(341.5201, grad_fn=<MseLossBackward>)
# tensor(222.0149, grad_fn=<MseLossBackward>)
# tensor(260.5952, grad_fn=<MseLossBackward>)
# tensor(88.2653, grad_fn=<MseLossBackward>)
# tensor(153.1823, grad_fn=<MseLossBackward>)
# tensor(184.0402, grad_fn=<MseLossBackward>)
# tensor(35.8462, grad_fn=<MseLossBackward>)
# tensor(147.3153, grad_fn=<MseLossBackward>)
# tensor(49.2882, grad_fn=<MseLossBackward>)
# tensor(154.9492, grad_fn=<MseLossBackward>)
# tensor(267.9467, grad_fn=<MseLossBackward>)
# tensor(23.1266, grad_fn=<MseLossBackward>)
# tensor(22.8677, grad_fn=<MseLossBackward>)
# tensor(136.3808, grad_fn=<MseLossBackward>)
# tensor(81.0289, grad_fn=<MseLossBackward>)
# tensor(90.3247, grad_fn=<MseLossBackward>)
# tensor(202.1782, grad_fn=<MseLossBackward>)
# tensor(13.6786, grad_fn=<MseLossBackward>)
# tensor(46.1968, grad_fn=<MseLossBackward>)
# tensor(14.0284, grad_fn=<MseLossBackward>)
# tensor(29.7628, grad_fn=<MseLossBackward>)
# tensor(8.7602, grad_fn=<MseLossBackward>)
# tensor(110.7470, grad_fn=<MseLossBackward>)
# tensor(113.8910, grad_fn=<MseLossBackward>)
# tensor(104.8068, grad_fn=<MseLossBackward>)
# tensor(29.2691, grad_fn=<MseLossBackward>)
# tensor(195.0007, grad_fn=<MseLossBackward>)
# tensor(31.0482, grad_fn=<MseLossBackward>)
# tensor(109.5110, grad_fn=<MseLossBackward>)
# tensor(12.9590, grad_fn=<MseLossBackward>)
# tensor(160.2802, grad_fn=<MseLossBackward>)
# tensor(12.9697, grad_fn=<MseLossBackward>)
# tensor(9.7110, grad_fn=<MseLossBackward>)
# tensor(44.7396, grad_fn=<MseLossBackward>)
# tensor(137.2360, grad_fn=<MseLossBackward>)
# tensor(91.0440, grad_fn=<MseLossBackward>)
# tensor(102.1912, grad_fn=<MseLossBackward>)
# tensor(6.4188, grad_fn=<MseLossBackward>)
# tensor(85.3230, grad_fn=<MseLossBackward>)
# tensor(25.1980, grad_fn=<MseLossBackward>)
# tensor(122.1535, grad_fn=<MseLossBackward>)
# tensor(87.2030, grad_fn=<MseLossBackward>)
# tensor(58.1558, grad_fn=<MseLossBackward>)
# tensor(62.0256, grad_fn=<MseLossBackward>)
# tensor(9.1003, grad_fn=<MseLossBackward>)
# tensor(57.3347, grad_fn=<MseLossBackward>)
# tensor(55.4515, grad_fn=<MseLossBackward>)
# tensor(49.4267, grad_fn=<MseLossBackward>)
# tensor(8.7738, grad_fn=<MseLossBackward>)
# tensor(13.0239, grad_fn=<MseLossBackward>)
# tensor(17.9525, grad_fn=<MseLossBackward>)
# tensor(94.0895, grad_fn=<MseLossBackward>)
# tensor(47.5225, grad_fn=<MseLossBackward>)
# tensor(90.9412, grad_fn=<MseLossBackward>)
# tensor(77.7399, grad_fn=<MseLossBackward>)
# tensor(151.7915, grad_fn=<MseLossBackward>)
# tensor(14.2972, grad_fn=<MseLossBackward>)
# tensor(66.3491, grad_fn=<MseLossBackward>)
# tensor(99.7507, grad_fn=<MseLossBackward>)
# tensor(22.3530, grad_fn=<MseLossBackward>)
# tensor(70.2098, grad_fn=<MseLossBackward>)
# tensor(38.5873, grad_fn=<MseLossBackward>)
# tensor(31.9538, grad_fn=<MseLossBackward>)
# tensor(16.0259, grad_fn=<MseLossBackward>)
# tensor(22.7103, grad_fn=<MseLossBackward>)
# tensor(86.7153, grad_fn=<MseLossBackward>)
# tensor(73.2175, grad_fn=<MseLossBackward>)
# tensor(71.3018, grad_fn=<MseLossBackward>)
# tensor(87.8225, grad_fn=<MseLossBackward>)
# tensor(65.0426, grad_fn=<MseLossBackward>)
# tensor(84.6069, grad_fn=<MseLossBackward>)
# tensor(23.8027, grad_fn=<MseLossBackward>)
# tensor(112.0613, grad_fn=<MseLossBackward>)
# tensor(42.5469, grad_fn=<MseLossBackward>)
# tensor(54.5771, grad_fn=<MseLossBackward>)
# tensor(83.1364, grad_fn=<MseLossBackward>)
# tensor(56.8721, grad_fn=<MseLossBackward>)
# tensor(54.6059, grad_fn=<MseLossBackward>)
# tensor(55.6806, grad_fn=<MseLossBackward>)
# tensor(11.7535, grad_fn=<MseLossBackward>)
# tensor(34.4809, grad_fn=<MseLossBackward>)
# tensor(12.5968, grad_fn=<MseLossBackward>)
# tensor(12.5971, grad_fn=<MseLossBackward>)
# tensor(29.7302, grad_fn=<MseLossBackward>)
# tensor(24.7149, grad_fn=<MseLossBackward>)
# tensor(72.3008, grad_fn=<MseLossBackward>)
# tensor(37.0192, grad_fn=<MseLossBackward>)
# tensor(61.9044, grad_fn=<MseLossBackward>)
# tensor(11.9726, grad_fn=<MseLossBackward>)
# tensor(10.1552, grad_fn=<MseLossBackward>)
# tensor(44.8772, grad_fn=<MseLossBackward>)
# tensor(28.9519, grad_fn=<MseLossBackward>)
# tensor(24.4477, grad_fn=<MseLossBackward>)
# tensor(27.2719, grad_fn=<MseLossBackward>)
# tensor(30.5023, grad_fn=<MseLossBackward>)
# tensor(35.9609, grad_fn=<MseLossBackward>)
# tensor(44.0813, grad_fn=<MseLossBackward>)
# tensor(23.0292, grad_fn=<MseLossBackward>)
# tensor(21.2031, grad_fn=<MseLossBackward>)
# tensor(70.1992, grad_fn=<MseLossBackward>)
# tensor(5.0221, grad_fn=<MseLossBackward>)
# tensor(64.0593, grad_fn=<MseLossBackward>)
# tensor(22.1380, grad_fn=<MseLossBackward>)
# tensor(22.1581, grad_fn=<MseLossBackward>)
# tensor(30.0777, grad_fn=<MseLossBackward>)
# tensor(33.5687, grad_fn=<MseLossBackward>)
# tensor(17.3255, grad_fn=<MseLossBackward>)
# tensor(37.1012, grad_fn=<MseLossBackward>)
# tensor(36.1157, grad_fn=<MseLossBackward>)
# tensor(4.3513, grad_fn=<MseLossBackward>)
# tensor(17.7517, grad_fn=<MseLossBackward>)
# tensor(9.4082, grad_fn=<MseLossBackward>)
# tensor(8.8189, grad_fn=<MseLossBackward>)
# tensor(7.2468, grad_fn=<MseLossBackward>)
# tensor(32.5001, grad_fn=<MseLossBackward>)
# tensor(7.0834, grad_fn=<MseLossBackward>)
# tensor(18.9287, grad_fn=<MseLossBackward>)
# tensor(17.2562, grad_fn=<MseLossBackward>)
# tensor(44.0542, grad_fn=<MseLossBackward>)
# tensor(43.4187, grad_fn=<MseLossBackward>)
# tensor(6.6265, grad_fn=<MseLossBackward>)
# tensor(38.2261, grad_fn=<MseLossBackward>)
# tensor(13.4132, grad_fn=<MseLossBackward>)
# tensor(4.0274, grad_fn=<MseLossBackward>)
# tensor(17.8399, grad_fn=<MseLossBackward>)
# tensor(45.1118, grad_fn=<MseLossBackward>)
# tensor(7.3565, grad_fn=<MseLossBackward>)
# tensor(2.0567, grad_fn=<MseLossBackward>)
# tensor(26.8823, grad_fn=<MseLossBackward>)
# tensor(8.0639, grad_fn=<MseLossBackward>)
# tensor(27.0844, grad_fn=<MseLossBackward>)
# tensor(24.0540, grad_fn=<MseLossBackward>)
# tensor(17.2152, grad_fn=<MseLossBackward>)
# tensor(44.0373, grad_fn=<MseLossBackward>)
# tensor(5.7744, grad_fn=<MseLossBackward>)
# tensor(24.9833, grad_fn=<MseLossBackward>)
# tensor(50.9776, grad_fn=<MseLossBackward>)
# tensor(45.9982, grad_fn=<MseLossBackward>)
# tensor(5.2123, grad_fn=<MseLossBackward>)
# tensor(48.0011, grad_fn=<MseLossBackward>)
# tensor(22.1482, grad_fn=<MseLossBackward>)
# tensor(15.2496, grad_fn=<MseLossBackward>)
# tensor(8.7633, grad_fn=<MseLossBackward>)
# tensor(22.5744, grad_fn=<MseLossBackward>)
# tensor(4.5935, grad_fn=<MseLossBackward>)
# tensor(21.2681, grad_fn=<MseLossBackward>)
# tensor(25.6934, grad_fn=<MseLossBackward>)
# tensor(24.7310, grad_fn=<MseLossBackward>)
# tensor(8.6524, grad_fn=<MseLossBackward>)
# tensor(26.9763, grad_fn=<MseLossBackward>)
# tensor(25.8943, grad_fn=<MseLossBackward>)
# tensor(21.9709, grad_fn=<MseLossBackward>)
# tensor(12.2733, grad_fn=<MseLossBackward>)
# tensor(33.3234, grad_fn=<MseLossBackward>)
# tensor(39.1972, grad_fn=<MseLossBackward>)
# tensor(29.5517, grad_fn=<MseLossBackward>)
# tensor(21.9202, grad_fn=<MseLossBackward>)
# tensor(3.5649, grad_fn=<MseLossBackward>)
# tensor(21.7209, grad_fn=<MseLossBackward>)
# tensor(37.2533, grad_fn=<MseLossBackward>)
# tensor(12.7715, grad_fn=<MseLossBackward>)
# tensor(23.0778, grad_fn=<MseLossBackward>)
# tensor(11.3899, grad_fn=<MseLossBackward>)
# tensor(27.8869, grad_fn=<MseLossBackward>)
# tensor(22.9029, grad_fn=<MseLossBackward>)
# tensor(9.3131, grad_fn=<MseLossBackward>)
# tensor(12.7357, grad_fn=<MseLossBackward>)
# tensor(23.5805, grad_fn=<MseLossBackward>)
# tensor(18.3837, grad_fn=<MseLossBackward>)
# tensor(6.8025, grad_fn=<MseLossBackward>)
# tensor(11.5454, grad_fn=<MseLossBackward>)
# tensor(10.9684, grad_fn=<MseLossBackward>)
# tensor(1.4866, grad_fn=<MseLossBackward>)
# tensor(24.8811, grad_fn=<MseLossBackward>)
# tensor(10.9966, grad_fn=<MseLossBackward>)
# tensor(9.1188, grad_fn=<MseLossBackward>)
# tensor(4.7329, grad_fn=<MseLossBackward>)
# tensor(2.8344, grad_fn=<MseLossBackward>)
# tensor(26.0680, grad_fn=<MseLossBackward>)
# tensor(23.0853, grad_fn=<MseLossBackward>)
# tensor(17.1611, grad_fn=<MseLossBackward>)
# tensor(2.9859, grad_fn=<MseLossBackward>)
# tensor(7.2770, grad_fn=<MseLossBackward>)
# tensor(24.2101, grad_fn=<MseLossBackward>)
# tensor(17.5087, grad_fn=<MseLossBackward>)
# tensor(20.8928, grad_fn=<MseLossBackward>)
# tensor(14.0149, grad_fn=<MseLossBackward>)
# tensor(19.7997, grad_fn=<MseLossBackward>)
# tensor(18.6801, grad_fn=<MseLossBackward>)
# tensor(12.5827, grad_fn=<MseLossBackward>)
# tensor(5.0679, grad_fn=<MseLossBackward>)
# tensor(14.5067, grad_fn=<MseLossBackward>)
# tensor(7.3145, grad_fn=<MseLossBackward>)
# tensor(10.6902, grad_fn=<MseLossBackward>)
# tensor(13.1352, grad_fn=<MseLossBackward>)
# tensor(10.3065, grad_fn=<MseLossBackward>)
# tensor(13.7121, grad_fn=<MseLossBackward>)
# tensor(23.2691, grad_fn=<MseLossBackward>)
# tensor(12.1993, grad_fn=<MseLossBackward>)
# tensor(8.2351, grad_fn=<MseLossBackward>)
# tensor(8.2407, grad_fn=<MseLossBackward>)
# tensor(21.1328, grad_fn=<MseLossBackward>)
# tensor(11.8209, grad_fn=<MseLossBackward>)
# tensor(10.0541, grad_fn=<MseLossBackward>)
# tensor(8.3082, grad_fn=<MseLossBackward>)
# tensor(6.2786, grad_fn=<MseLossBackward>)
# tensor(4.5089, grad_fn=<MseLossBackward>)
# tensor(5.1267, grad_fn=<MseLossBackward>)
# tensor(8.0525, grad_fn=<MseLossBackward>)
# tensor(13.5022, grad_fn=<MseLossBackward>)
# tensor(10.9674, grad_fn=<MseLossBackward>)
# tensor(13.5079, grad_fn=<MseLossBackward>)
# tensor(23.7915, grad_fn=<MseLossBackward>)
# tensor(5.2044, grad_fn=<MseLossBackward>)
# tensor(9.1159, grad_fn=<MseLossBackward>)
# tensor(11.3289, grad_fn=<MseLossBackward>)
# tensor(13.1583, grad_fn=<MseLossBackward>)
# tensor(12.1146, grad_fn=<MseLossBackward>)
# tensor(3.5168, grad_fn=<MseLossBackward>)
# tensor(4.0812, grad_fn=<MseLossBackward>)
# tensor(4.5497, grad_fn=<MseLossBackward>)
# tensor(5.9599, grad_fn=<MseLossBackward>)
# tensor(11.0185, grad_fn=<MseLossBackward>)
# tensor(3.0938, grad_fn=<MseLossBackward>)
# tensor(8.2173, grad_fn=<MseLossBackward>)
# tensor(10.9500, grad_fn=<MseLossBackward>)
# tensor(6.3511, grad_fn=<MseLossBackward>)
# tensor(3.4926, grad_fn=<MseLossBackward>)
# tensor(12.6735, grad_fn=<MseLossBackward>)
# tensor(4.2559, grad_fn=<MseLossBackward>)
# tensor(3.3546, grad_fn=<MseLossBackward>)
# tensor(9.3184, grad_fn=<MseLossBackward>)
# tensor(5.1517, grad_fn=<MseLossBackward>)
# tensor(2.9945, grad_fn=<MseLossBackward>)
# tensor(9.6351, grad_fn=<MseLossBackward>)
# tensor(10.8159, grad_fn=<MseLossBackward>)
# tensor(2.9728, grad_fn=<MseLossBackward>)
# tensor(5.5417, grad_fn=<MseLossBackward>)
# tensor(4.6162, grad_fn=<MseLossBackward>)
# tensor(11.3654, grad_fn=<MseLossBackward>)
# tensor(1.1247, grad_fn=<MseLossBackward>)
# tensor(10.7179, grad_fn=<MseLossBackward>)
# tensor(6.8786, grad_fn=<MseLossBackward>)
# tensor(5.5407, grad_fn=<MseLossBackward>)
# tensor(2.2984, grad_fn=<MseLossBackward>)
# tensor(5.3042, grad_fn=<MseLossBackward>)
# tensor(5.1434, grad_fn=<MseLossBackward>)
# tensor(7.0806, grad_fn=<MseLossBackward>)
# tensor(12.0048, grad_fn=<MseLossBackward>)
# tensor(4.2017, grad_fn=<MseLossBackward>)
# tensor(3.1375, grad_fn=<MseLossBackward>)
# tensor(5.5107, grad_fn=<MseLossBackward>)
# tensor(5.0768, grad_fn=<MseLossBackward>)
# tensor(9.7903, grad_fn=<MseLossBackward>)
# tensor(4.0138, grad_fn=<MseLossBackward>)
# tensor(3.7483, grad_fn=<MseLossBackward>)
# tensor(8.6378, grad_fn=<MseLossBackward>)
# tensor(5.1328, grad_fn=<MseLossBackward>)
# tensor(1.1892, grad_fn=<MseLossBackward>)
# tensor(5.7886, grad_fn=<MseLossBackward>)
# tensor(8.5816, grad_fn=<MseLossBackward>)
# tensor(5.3808, grad_fn=<MseLossBackward>)
# tensor(2.0918, grad_fn=<MseLossBackward>)
# tensor(3.0943, grad_fn=<MseLossBackward>)
# tensor(1.2411, grad_fn=<MseLossBackward>)
# tensor(2.3544, grad_fn=<MseLossBackward>)
# tensor(1.7212, grad_fn=<MseLossBackward>)
# tensor(2.5126, grad_fn=<MseLossBackward>)
# tensor(1.4507, grad_fn=<MseLossBackward>)
# tensor(1.9887, grad_fn=<MseLossBackward>)
# tensor(4.3614, grad_fn=<MseLossBackward>)
# tensor(1.5849, grad_fn=<MseLossBackward>)
# tensor(3.2740, grad_fn=<MseLossBackward>)
# tensor(1.4071, grad_fn=<MseLossBackward>)
# tensor(4.3970, grad_fn=<MseLossBackward>)
# tensor(1.6563, grad_fn=<MseLossBackward>)
# tensor(1.3885, grad_fn=<MseLossBackward>)
# tensor(6.9545, grad_fn=<MseLossBackward>)
# tensor(2.0326, grad_fn=<MseLossBackward>)
# tensor(0.9555, grad_fn=<MseLossBackward>)
# tensor(3.9052, grad_fn=<MseLossBackward>)
# tensor(7.1290, grad_fn=<MseLossBackward>)
# tensor(2.8335, grad_fn=<MseLossBackward>)
# tensor(0.4897, grad_fn=<MseLossBackward>)
# tensor(5.1568, grad_fn=<MseLossBackward>)
# tensor(4.1821, grad_fn=<MseLossBackward>)
# tensor(2.7161, grad_fn=<MseLossBackward>)
# tensor(2.3867, grad_fn=<MseLossBackward>)
# tensor(3.8773, grad_fn=<MseLossBackward>)
# tensor(2.1968, grad_fn=<MseLossBackward>)
# tensor(2.0504, grad_fn=<MseLossBackward>)
# tensor(2.5281, grad_fn=<MseLossBackward>)
# tensor(1.9031, grad_fn=<MseLossBackward>)
# tensor(0.9537, grad_fn=<MseLossBackward>)
# tensor(1.8099, grad_fn=<MseLossBackward>)
# tensor(2.1685, grad_fn=<MseLossBackward>)
# tensor(2.2005, grad_fn=<MseLossBackward>)
# tensor(1.0453, grad_fn=<MseLossBackward>)
# tensor(2.1241, grad_fn=<MseLossBackward>)
# tensor(2.8805, grad_fn=<MseLossBackward>)
# tensor(1.3052, grad_fn=<MseLossBackward>)
# tensor(9.9349, grad_fn=<MseLossBackward>)
# tensor(0.7026, grad_fn=<MseLossBackward>)
# tensor(0.9778, grad_fn=<MseLossBackward>)
# tensor(0.9692, grad_fn=<MseLossBackward>)
# tensor(9.8611, grad_fn=<MseLossBackward>)
# tensor(2.4436, grad_fn=<MseLossBackward>)
# tensor(0.5734, grad_fn=<MseLossBackward>)
# tensor(1.1627, grad_fn=<MseLossBackward>)
# tensor(0.6371, grad_fn=<MseLossBackward>)
# tensor(5.6191, grad_fn=<MseLossBackward>)
# tensor(2.6840, grad_fn=<MseLossBackward>)
# tensor(2.4459, grad_fn=<MseLossBackward>)
# tensor(1.1758, grad_fn=<MseLossBackward>)
# tensor(2.4187, grad_fn=<MseLossBackward>)
# tensor(2.9304, grad_fn=<MseLossBackward>)
# tensor(4.6966, grad_fn=<MseLossBackward>)
# tensor(0.9147, grad_fn=<MseLossBackward>)
# tensor(5.4922, grad_fn=<MseLossBackward>)
# tensor(2.1336, grad_fn=<MseLossBackward>)
# tensor(1.0608, grad_fn=<MseLossBackward>)
# tensor(4.6026, grad_fn=<MseLossBackward>)
# tensor(0.8658, grad_fn=<MseLossBackward>)
# tensor(4.6816, grad_fn=<MseLossBackward>)
# tensor(0.8158, grad_fn=<MseLossBackward>)
# tensor(2.1329, grad_fn=<MseLossBackward>)
# tensor(1.0350, grad_fn=<MseLossBackward>)
# tensor(2.4261, grad_fn=<MseLossBackward>)
# tensor(2.3417, grad_fn=<MseLossBackward>)
# tensor(6.6944, grad_fn=<MseLossBackward>)
# tensor(2.1012, grad_fn=<MseLossBackward>)
# tensor(5.2931, grad_fn=<MseLossBackward>)
# tensor(1.8198, grad_fn=<MseLossBackward>)
# tensor(1.5762, grad_fn=<MseLossBackward>)
# tensor(3.2673, grad_fn=<MseLossBackward>)
# tensor(4.4252, grad_fn=<MseLossBackward>)
# tensor(2.5315, grad_fn=<MseLossBackward>)
# tensor(1.0004, grad_fn=<MseLossBackward>)
# tensor(5.1688, grad_fn=<MseLossBackward>)
# tensor(4.9825, grad_fn=<MseLossBackward>)
# tensor(3.8352, grad_fn=<MseLossBackward>)
# tensor(1.1869, grad_fn=<MseLossBackward>)
# tensor(0.7312, grad_fn=<MseLossBackward>)
# tensor(1.3631, grad_fn=<MseLossBackward>)
# tensor(2.3961, grad_fn=<MseLossBackward>)
# tensor(3.1820, grad_fn=<MseLossBackward>)
# tensor(2.6354, grad_fn=<MseLossBackward>)
# tensor(1.5476, grad_fn=<MseLossBackward>)
# tensor(3.8440, grad_fn=<MseLossBackward>)
# tensor(0.9835, grad_fn=<MseLossBackward>)
# tensor(1.7886, grad_fn=<MseLossBackward>)
# tensor(3.7248, grad_fn=<MseLossBackward>)
# tensor(4.5478, grad_fn=<MseLossBackward>)
# tensor(0.5898, grad_fn=<MseLossBackward>)
# tensor(1.3494, grad_fn=<MseLossBackward>)
# tensor(1.0026, grad_fn=<MseLossBackward>)
# tensor(2.8863, grad_fn=<MseLossBackward>)
# tensor(1.3093, grad_fn=<MseLossBackward>)
# tensor(0.8242, grad_fn=<MseLossBackward>)
# tensor(0.7170, grad_fn=<MseLossBackward>)
# tensor(9.2988, grad_fn=<MseLossBackward>)
# tensor(0.9880, grad_fn=<MseLossBackward>)
# tensor(2.0657, grad_fn=<MseLossBackward>)
# tensor(1.3689, grad_fn=<MseLossBackward>)
# tensor(3.1540, grad_fn=<MseLossBackward>)
# tensor(1.0524, grad_fn=<MseLossBackward>)
# tensor(1.5080, grad_fn=<MseLossBackward>)
# tensor(0.6826, grad_fn=<MseLossBackward>)
# tensor(0.7712, grad_fn=<MseLossBackward>)
# tensor(0.2648, grad_fn=<MseLossBackward>)
# tensor(6.1966, grad_fn=<MseLossBackward>)
# tensor(0.6679, grad_fn=<MseLossBackward>)
# tensor(1.4447, grad_fn=<MseLossBackward>)
# tensor(1.0330, grad_fn=<MseLossBackward>)
# tensor(0.7975, grad_fn=<MseLossBackward>)
# tensor(3.2697, grad_fn=<MseLossBackward>)
# tensor(5.4209, grad_fn=<MseLossBackward>)
# tensor(0.9843, grad_fn=<MseLossBackward>)
# tensor(2.4165, grad_fn=<MseLossBackward>)
# tensor(2.1716, grad_fn=<MseLossBackward>)
# tensor(3.4452, grad_fn=<MseLossBackward>)
# tensor(2.8939, grad_fn=<MseLossBackward>)
# tensor(2.2464, grad_fn=<MseLossBackward>)
# tensor(1.0797, grad_fn=<MseLossBackward>)
# tensor(1.1639, grad_fn=<MseLossBackward>)
# tensor(1.0547, grad_fn=<MseLossBackward>)
# tensor(3.0327, grad_fn=<MseLossBackward>)
# tensor(1.7027, grad_fn=<MseLossBackward>)
# tensor(3.0222, grad_fn=<MseLossBackward>)
# tensor(0.7074, grad_fn=<MseLossBackward>)
# tensor(2.8120, grad_fn=<MseLossBackward>)
# tensor(1.0112, grad_fn=<MseLossBackward>)
# tensor(1.7957, grad_fn=<MseLossBackward>)
# tensor(4.2781, grad_fn=<MseLossBackward>)
# tensor(2.1743, grad_fn=<MseLossBackward>)
# tensor(1.1048, grad_fn=<MseLossBackward>)
# tensor(3.6393, grad_fn=<MseLossBackward>)
# tensor(3.0271, grad_fn=<MseLossBackward>)
# tensor(1.1317, grad_fn=<MseLossBackward>)
# tensor(2.4657, grad_fn=<MseLossBackward>)
# tensor(0.9266, grad_fn=<MseLossBackward>)
# tensor(2.1042, grad_fn=<MseLossBackward>)
# tensor(4.8999, grad_fn=<MseLossBackward>)
# tensor(2.6048, grad_fn=<MseLossBackward>)
# tensor(0.3991, grad_fn=<MseLossBackward>)
# tensor(2.3680, grad_fn=<MseLossBackward>)
# tensor(1.8102, grad_fn=<MseLossBackward>)
# tensor(2.9144, grad_fn=<MseLossBackward>)
# tensor(2.3262, grad_fn=<MseLossBackward>)
# tensor(1.5583, grad_fn=<MseLossBackward>)
# tensor(1.6466, grad_fn=<MseLossBackward>)
# tensor(0.4731, grad_fn=<MseLossBackward>)
# tensor(1.6353, grad_fn=<MseLossBackward>)
# tensor(0.3291, grad_fn=<MseLossBackward>)
# tensor(3.4171, grad_fn=<MseLossBackward>)
# tensor(2.9259, grad_fn=<MseLossBackward>)
# tensor(2.1163, grad_fn=<MseLossBackward>)
# tensor(0.5865, grad_fn=<MseLossBackward>)
# tensor(1.1893, grad_fn=<MseLossBackward>)
# tensor(1.6875, grad_fn=<MseLossBackward>)
# tensor(0.4341, grad_fn=<MseLossBackward>)
# tensor(0.4402, grad_fn=<MseLossBackward>)
# tensor(1.9188, grad_fn=<MseLossBackward>)
# tensor(1.7117, grad_fn=<MseLossBackward>)
# tensor(2.0692, grad_fn=<MseLossBackward>)
# tensor(0.6499, grad_fn=<MseLossBackward>)
# tensor(2.2691, grad_fn=<MseLossBackward>)
# tensor(0.8960, grad_fn=<MseLossBackward>)
# tensor(3.1312, grad_fn=<MseLossBackward>)
# tensor(2.6885, grad_fn=<MseLossBackward>)
# tensor(1.9924, grad_fn=<MseLossBackward>)
# tensor(0.6350, grad_fn=<MseLossBackward>)
# tensor(3.0636, grad_fn=<MseLossBackward>)
# tensor(1.5297, grad_fn=<MseLossBackward>)
# tensor(0.3036, grad_fn=<MseLossBackward>)
# tensor(1.0648, grad_fn=<MseLossBackward>)
# tensor(0.6442, grad_fn=<MseLossBackward>)
# tensor(2.5466, grad_fn=<MseLossBackward>)
# tensor(1.9072, grad_fn=<MseLossBackward>)
# tensor(1.5492, grad_fn=<MseLossBackward>)
# tensor(1.6054, grad_fn=<MseLossBackward>)
# tensor(1.2417, grad_fn=<MseLossBackward>)
# tensor(0.7771, grad_fn=<MseLossBackward>)
# tensor(1.1030, grad_fn=<MseLossBackward>)
# tensor(0.4693, grad_fn=<MseLossBackward>)
# tensor(1.0689, grad_fn=<MseLossBackward>)
# tensor(0.8685, grad_fn=<MseLossBackward>)
# tensor(2.1598, grad_fn=<MseLossBackward>)
# tensor(0.6194, grad_fn=<MseLossBackward>)
# tensor(3.1758, grad_fn=<MseLossBackward>)
# tensor(1.2514, grad_fn=<MseLossBackward>)
# tensor(1.4903, grad_fn=<MseLossBackward>)
# tensor(1.8475, grad_fn=<MseLossBackward>)
# tensor(2.5256, grad_fn=<MseLossBackward>)
# tensor(2.7955, grad_fn=<MseLossBackward>)
# tensor(2.8065, grad_fn=<MseLossBackward>)
# tensor(1.6345, grad_fn=<MseLossBackward>)
# tensor(0.8992, grad_fn=<MseLossBackward>)
# tensor(0.4865, grad_fn=<MseLossBackward>)
# tensor(2.4766, grad_fn=<MseLossBackward>)
# tensor(0.9155, grad_fn=<MseLossBackward>)
# tensor(0.6167, grad_fn=<MseLossBackward>)
# tensor(1.7532, grad_fn=<MseLossBackward>)
# tensor(2.6536, grad_fn=<MseLossBackward>)
# tensor(1.4669, grad_fn=<MseLossBackward>)
# tensor(1.7591, grad_fn=<MseLossBackward>)
# tensor(0.5656, grad_fn=<MseLossBackward>)
# tensor(1.5196, grad_fn=<MseLossBackward>)
# tensor(1.9937, grad_fn=<MseLossBackward>)
# tensor(0.5051, grad_fn=<MseLossBackward>)
# tensor(0.2618, grad_fn=<MseLossBackward>)
# tensor(2.1504, grad_fn=<MseLossBackward>)
# tensor(0.5735, grad_fn=<MseLossBackward>)
# tensor(0.5696, grad_fn=<MseLossBackward>)
# tensor(1.6019, grad_fn=<MseLossBackward>)
# tensor(1.5687, grad_fn=<MseLossBackward>)
# tensor(4.0179, grad_fn=<MseLossBackward>)
# tensor(1.8064, grad_fn=<MseLossBackward>)
# tensor(1.0897, grad_fn=<MseLossBackward>)
# tensor(0.6291, grad_fn=<MseLossBackward>)
# tensor(0.6340, grad_fn=<MseLossBackward>)
# tensor(1.1369, grad_fn=<MseLossBackward>)
# tensor(0.4924, grad_fn=<MseLossBackward>)
# tensor(0.4605, grad_fn=<MseLossBackward>)
# tensor(2.8578, grad_fn=<MseLossBackward>)
# tensor(1.2413, grad_fn=<MseLossBackward>)
# tensor(0.2501, grad_fn=<MseLossBackward>)
# tensor(2.3253, grad_fn=<MseLossBackward>)
# tensor(2.7103, grad_fn=<MseLossBackward>)
# tensor(1.3449, grad_fn=<MseLossBackward>)
# tensor(0.3725, grad_fn=<MseLossBackward>)
# tensor(1.5014, grad_fn=<MseLossBackward>)
# tensor(0.3675, grad_fn=<MseLossBackward>)
# tensor(0.6388, grad_fn=<MseLossBackward>)
# tensor(1.7339, grad_fn=<MseLossBackward>)
# tensor(1.5480, grad_fn=<MseLossBackward>)
# tensor(1.0869, grad_fn=<MseLossBackward>)
# tensor(0.4636, grad_fn=<MseLossBackward>)
# tensor(0.5152, grad_fn=<MseLossBackward>)
# tensor(1.6024, grad_fn=<MseLossBackward>)
# tensor(0.9008, grad_fn=<MseLossBackward>)
# tensor(1.4495, grad_fn=<MseLossBackward>)
# tensor(0.7909, grad_fn=<MseLossBackward>)
# tensor(0.4181, grad_fn=<MseLossBackward>)
# tensor(0.5613, grad_fn=<MseLossBackward>)
# tensor(0.4457, grad_fn=<MseLossBackward>)
# tensor(2.6335, grad_fn=<MseLossBackward>)
# tensor(2.2918, grad_fn=<MseLossBackward>)
# tensor(2.0079, grad_fn=<MseLossBackward>)
# tensor(0.4376, grad_fn=<MseLossBackward>)
# tensor(0.4107, grad_fn=<MseLossBackward>)
# tensor(2.3810, grad_fn=<MseLossBackward>)
# tensor(1.2981, grad_fn=<MseLossBackward>)
# tensor(0.5393, grad_fn=<MseLossBackward>)
# tensor(0.5154, grad_fn=<MseLossBackward>)
# tensor(2.5830, grad_fn=<MseLossBackward>)
# tensor(1.1969, grad_fn=<MseLossBackward>)
# tensor(0.9420, grad_fn=<MseLossBackward>)
# tensor(0.3132, grad_fn=<MseLossBackward>)
# tensor(1.1835, grad_fn=<MseLossBackward>)
# tensor(0.5260, grad_fn=<MseLossBackward>)
# tensor(0.4042, grad_fn=<MseLossBackward>)
# tensor(0.3261, grad_fn=<MseLossBackward>)
# tensor(1.5075, grad_fn=<MseLossBackward>)
# tensor(0.5267, grad_fn=<MseLossBackward>)
# tensor(0.8650, grad_fn=<MseLossBackward>)
# tensor(0.6873, grad_fn=<MseLossBackward>)
# tensor(0.6437, grad_fn=<MseLossBackward>)
# tensor(1.1859, grad_fn=<MseLossBackward>)
# tensor(2.8784, grad_fn=<MseLossBackward>)
# tensor(0.3403, grad_fn=<MseLossBackward>)
# tensor(0.6587, grad_fn=<MseLossBackward>)
# tensor(1.0289, grad_fn=<MseLossBackward>)
# tensor(1.5695, grad_fn=<MseLossBackward>)
# tensor(1.8281, grad_fn=<MseLossBackward>)
# tensor(0.9457, grad_fn=<MseLossBackward>)
# tensor(0.3949, grad_fn=<MseLossBackward>)
# tensor(0.6535, grad_fn=<MseLossBackward>)
# tensor(0.6138, grad_fn=<MseLossBackward>)
# tensor(0.9650, grad_fn=<MseLossBackward>)
# tensor(1.4438, grad_fn=<MseLossBackward>)
# tensor(1.7048, grad_fn=<MseLossBackward>)
# tensor(0.1889, grad_fn=<MseLossBackward>)
# tensor(0.3818, grad_fn=<MseLossBackward>)
# tensor(0.3423, grad_fn=<MseLossBackward>)
# tensor(1.4439, grad_fn=<MseLossBackward>)
# tensor(0.6259, grad_fn=<MseLossBackward>)
# tensor(1.8458, grad_fn=<MseLossBackward>)
# tensor(0.5467, grad_fn=<MseLossBackward>)
# tensor(1.4526, grad_fn=<MseLossBackward>)
# tensor(0.3203, grad_fn=<MseLossBackward>)
# tensor(0.1989, grad_fn=<MseLossBackward>)
# tensor(0.7542, grad_fn=<MseLossBackward>)
# tensor(2.8291, grad_fn=<MseLossBackward>)
# tensor(0.4844, grad_fn=<MseLossBackward>)
# tensor(0.6652, grad_fn=<MseLossBackward>)
# tensor(1.1856, grad_fn=<MseLossBackward>)
# tensor(0.4958, grad_fn=<MseLossBackward>)
# tensor(0.6785, grad_fn=<MseLossBackward>)
# tensor(1.6010, grad_fn=<MseLossBackward>)
# tensor(1.0194, grad_fn=<MseLossBackward>)
# tensor(0.4597, grad_fn=<MseLossBackward>)
# tensor(0.6563, grad_fn=<MseLossBackward>)
# tensor(1.1430, grad_fn=<MseLossBackward>)
# tensor(0.1779, grad_fn=<MseLossBackward>)
# tensor(0.5746, grad_fn=<MseLossBackward>)
# tensor(1.9643, grad_fn=<MseLossBackward>)
# tensor(1.0555, grad_fn=<MseLossBackward>)
# tensor(0.7570, grad_fn=<MseLossBackward>)
# tensor(0.3188, grad_fn=<MseLossBackward>)
# tensor(0.6224, grad_fn=<MseLossBackward>)
# tensor(2.7543, grad_fn=<MseLossBackward>)
# tensor(1.2772, grad_fn=<MseLossBackward>)
# tensor(1.0542, grad_fn=<MseLossBackward>)
# tensor(0.5942, grad_fn=<MseLossBackward>)
# tensor(0.2479, grad_fn=<MseLossBackward>)
# tensor(0.1944, grad_fn=<MseLossBackward>)
# tensor(0.5046, grad_fn=<MseLossBackward>)
# tensor(0.3239, grad_fn=<MseLossBackward>)
# tensor(0.7089, grad_fn=<MseLossBackward>)
# tensor(0.3325, grad_fn=<MseLossBackward>)
# tensor(0.8985, grad_fn=<MseLossBackward>)
# tensor(0.7440, grad_fn=<MseLossBackward>)
# tensor(0.2897, grad_fn=<MseLossBackward>)
# tensor(0.4300, grad_fn=<MseLossBackward>)
# tensor(0.7047, grad_fn=<MseLossBackward>)
# tensor(0.7899, grad_fn=<MseLossBackward>)
# tensor(1.3143, grad_fn=<MseLossBackward>)
# tensor(0.3879, grad_fn=<MseLossBackward>)
# tensor(0.7743, grad_fn=<MseLossBackward>)
# tensor(0.6019, grad_fn=<MseLossBackward>)
# tensor(1.4818, grad_fn=<MseLossBackward>)
# tensor(1.7286, grad_fn=<MseLossBackward>)
# tensor(0.5040, grad_fn=<MseLossBackward>)
# tensor(0.2826, grad_fn=<MseLossBackward>)
# tensor(0.3534, grad_fn=<MseLossBackward>)
# tensor(0.6671, grad_fn=<MseLossBackward>)
# tensor(0.3345, grad_fn=<MseLossBackward>)
# tensor(0.2186, grad_fn=<MseLossBackward>)
# tensor(0.2925, grad_fn=<MseLossBackward>)
# tensor(1.2959, grad_fn=<MseLossBackward>)
# tensor(0.1607, grad_fn=<MseLossBackward>)
# tensor(0.3209, grad_fn=<MseLossBackward>)
# tensor(0.8608, grad_fn=<MseLossBackward>)
# tensor(0.3199, grad_fn=<MseLossBackward>)
# tensor(0.4840, grad_fn=<MseLossBackward>)
# tensor(0.1756, grad_fn=<MseLossBackward>)
# tensor(1.5968, grad_fn=<MseLossBackward>)
# tensor(0.1212, grad_fn=<MseLossBackward>)
# tensor(0.8174, grad_fn=<MseLossBackward>)
# tensor(1.3530, grad_fn=<MseLossBackward>)
# tensor(0.6845, grad_fn=<MseLossBackward>)
# tensor(0.6430, grad_fn=<MseLossBackward>)
# tensor(1.0318, grad_fn=<MseLossBackward>)
# tensor(0.6236, grad_fn=<MseLossBackward>)
# tensor(1.6797, grad_fn=<MseLossBackward>)
# tensor(0.6112, grad_fn=<MseLossBackward>)
# tensor(0.6001, grad_fn=<MseLossBackward>)
# tensor(0.4060, grad_fn=<MseLossBackward>)
# tensor(0.3156, grad_fn=<MseLossBackward>)
# tensor(0.3571, grad_fn=<MseLossBackward>)
# tensor(0.4880, grad_fn=<MseLossBackward>)
# tensor(0.2139, grad_fn=<MseLossBackward>)
# tensor(0.2648, grad_fn=<MseLossBackward>)
# tensor(1.3734, grad_fn=<MseLossBackward>)
# tensor(0.2891, grad_fn=<MseLossBackward>)
# tensor(0.3861, grad_fn=<MseLossBackward>)
# tensor(0.1728, grad_fn=<MseLossBackward>)
# tensor(0.6716, grad_fn=<MseLossBackward>)
# tensor(0.8502, grad_fn=<MseLossBackward>)
# tensor(0.2394, grad_fn=<MseLossBackward>)
# tensor(0.2045, grad_fn=<MseLossBackward>)
# tensor(1.0351, grad_fn=<MseLossBackward>)
# tensor(0.6437, grad_fn=<MseLossBackward>)
# tensor(0.7738, grad_fn=<MseLossBackward>)
# tensor(0.4612, grad_fn=<MseLossBackward>)
# tensor(0.4488, grad_fn=<MseLossBackward>)
# tensor(0.6252, grad_fn=<MseLossBackward>)
# tensor(0.5786, grad_fn=<MseLossBackward>)
# tensor(0.4051, grad_fn=<MseLossBackward>)
# tensor(0.2864, grad_fn=<MseLossBackward>)
# tensor(0.3817, grad_fn=<MseLossBackward>)
# tensor(1.5154, grad_fn=<MseLossBackward>)
# tensor(0.4969, grad_fn=<MseLossBackward>)
# tensor(0.3121, grad_fn=<MseLossBackward>)
# tensor(0.2080, grad_fn=<MseLossBackward>)
# tensor(0.3096, grad_fn=<MseLossBackward>)
# tensor(0.5059, grad_fn=<MseLossBackward>)
# tensor(0.4788, grad_fn=<MseLossBackward>)
# tensor(0.1052, grad_fn=<MseLossBackward>)
# tensor(0.1632, grad_fn=<MseLossBackward>)
# tensor(0.2763, grad_fn=<MseLossBackward>)
# tensor(0.2090, grad_fn=<MseLossBackward>)
# tensor(1.7172, grad_fn=<MseLossBackward>)
# tensor(1.2689, grad_fn=<MseLossBackward>)
# tensor(0.7009, grad_fn=<MseLossBackward>)
# tensor(0.2750, grad_fn=<MseLossBackward>)
# tensor(0.4544, grad_fn=<MseLossBackward>)
# tensor(0.1873, grad_fn=<MseLossBackward>)
# tensor(0.5156, grad_fn=<MseLossBackward>)
# tensor(0.5129, grad_fn=<MseLossBackward>)
# tensor(0.2714, grad_fn=<MseLossBackward>)
# tensor(0.6225, grad_fn=<MseLossBackward>)
# tensor(0.2853, grad_fn=<MseLossBackward>)
# tensor(0.1633, grad_fn=<MseLossBackward>)
# tensor(0.1320, grad_fn=<MseLossBackward>)
# tensor(0.6428, grad_fn=<MseLossBackward>)
# tensor(1.4067, grad_fn=<MseLossBackward>)
# tensor(0.5963, grad_fn=<MseLossBackward>)
# tensor(0.4354, grad_fn=<MseLossBackward>)
# tensor(1.0959, grad_fn=<MseLossBackward>)
# tensor(0.3207, grad_fn=<MseLossBackward>)
# tensor(0.4891, grad_fn=<MseLossBackward>)
# tensor(0.5692, grad_fn=<MseLossBackward>)
# tensor(0.1839, grad_fn=<MseLossBackward>)
# tensor(0.1831, grad_fn=<MseLossBackward>)
# tensor(0.6034, grad_fn=<MseLossBackward>)
# tensor(1.0656, grad_fn=<MseLossBackward>)
# tensor(0.5486, grad_fn=<MseLossBackward>)
# tensor(0.7539, grad_fn=<MseLossBackward>)
# tensor(0.2737, grad_fn=<MseLossBackward>)
# tensor(0.9662, grad_fn=<MseLossBackward>)
# tensor(0.2352, grad_fn=<MseLossBackward>)
# tensor(0.5925, grad_fn=<MseLossBackward>)
# tensor(0.3598, grad_fn=<MseLossBackward>)
# tensor(0.6790, grad_fn=<MseLossBackward>)
# tensor(0.3435, grad_fn=<MseLossBackward>)
# tensor(0.4118, grad_fn=<MseLossBackward>)
# tensor(0.4812, grad_fn=<MseLossBackward>)
# tensor(0.2554, grad_fn=<MseLossBackward>)
# tensor(0.7015, grad_fn=<MseLossBackward>)
# tensor(0.2758, grad_fn=<MseLossBackward>)
# tensor(0.4196, grad_fn=<MseLossBackward>)
# tensor(0.5888, grad_fn=<MseLossBackward>)
# tensor(0.1808, grad_fn=<MseLossBackward>)
# tensor(0.1666, grad_fn=<MseLossBackward>)
# tensor(0.2549, grad_fn=<MseLossBackward>)
# tensor(0.5501, grad_fn=<MseLossBackward>)
# tensor(0.9095, grad_fn=<MseLossBackward>)
# tensor(0.2201, grad_fn=<MseLossBackward>)
# tensor(0.1376, grad_fn=<MseLossBackward>)
# tensor(0.1552, grad_fn=<MseLossBackward>)
# tensor(0.8783, grad_fn=<MseLossBackward>)
# tensor(0.2669, grad_fn=<MseLossBackward>)
# tensor(0.2006, grad_fn=<MseLossBackward>)
# tensor(0.1390, grad_fn=<MseLossBackward>)
# tensor(0.3410, grad_fn=<MseLossBackward>)
# tensor(0.6083, grad_fn=<MseLossBackward>)
# tensor(1.1246, grad_fn=<MseLossBackward>)
# tensor(0.2116, grad_fn=<MseLossBackward>)
# tensor(0.8537, grad_fn=<MseLossBackward>)
# tensor(0.3393, grad_fn=<MseLossBackward>)
# tensor(0.1856, grad_fn=<MseLossBackward>)
# tensor(0.3821, grad_fn=<MseLossBackward>)
# tensor(0.3901, grad_fn=<MseLossBackward>)
# tensor(0.7566, grad_fn=<MseLossBackward>)
# tensor(0.1640, grad_fn=<MseLossBackward>)
# tensor(0.2060, grad_fn=<MseLossBackward>)
# tensor(0.1651, grad_fn=<MseLossBackward>)
# tensor(0.0956, grad_fn=<MseLossBackward>)
# tensor(1.5325, grad_fn=<MseLossBackward>)
# tensor(0.2437, grad_fn=<MseLossBackward>)
# tensor(1.2120, grad_fn=<MseLossBackward>)
# tensor(0.8369, grad_fn=<MseLossBackward>)
# tensor(0.5098, grad_fn=<MseLossBackward>)
# tensor(0.3089, grad_fn=<MseLossBackward>)
# tensor(0.9492, grad_fn=<MseLossBackward>)
# tensor(0.7469, grad_fn=<MseLossBackward>)
# tensor(0.8485, grad_fn=<MseLossBackward>)
# tensor(0.2207, grad_fn=<MseLossBackward>)
# tensor(0.8355, grad_fn=<MseLossBackward>)
# tensor(0.1994, grad_fn=<MseLossBackward>)

# %%
model(torch_x).detach().numpy()
# Out:
# array([[ 0.07550856],
#        [-0.05987364],
#        [ 0.19688344],
#        ...,
#        [-0.07334246],
#        [-0.07782627],
#        [-0.21096814]], dtype=float32)

# %%
from sklearn.metrics import r2_score
